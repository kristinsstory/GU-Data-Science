# %% [markdown]
# **1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.**

# %%
from pprint import pprint
import requests
import json

# %%
main_link = 'https://api.github.com/users/Christinayar/repos'

# %%
response = requests.get(main_link)

# %%
data = response.json()
pprint(data)
# Out:
# [{'archive_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/branches{/branch}',
#   'clone_url': 'https://github.com/Christinayar/Geekbrains-Courseworks.git',
#   'collaborators_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/contributors',
#   'created_at': '2020-05-02T14:48:46Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/deployments',
#   'description': 'Курсовые итоговые проекты (Mysql; Python for Data Science)',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/downloads',
#   'events_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/forks',
#   'full_name': 'Christinayar/Geekbrains-Courseworks',
#   'git_commits_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/git/tags{/sha}',
#   'git_url': 'git://github.com/Christinayar/Geekbrains-Courseworks.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/hooks',
#   'html_url': 'https://github.com/Christinayar/Geekbrains-Courseworks',
#   'id': 260708623,
#   'issue_comment_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/merges',
#   'milestones_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Geekbrains-Courseworks',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjA3MDg2MjM=',
#   'notifications_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/49560511?v=4',
#             'events_url': 'https://api.github.com/users/Christinayar/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Christinayar/followers',
#             'following_url': 'https://api.github.com/users/Christinayar/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Christinayar/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Christinayar',
#             'id': 49560511,
#             'login': 'Christinayar',
#             'node_id': 'MDQ6VXNlcjQ5NTYwNTEx',
#             'organizations_url': 'https://api.github.com/users/Christinayar/orgs',
#             'received_events_url': 'https://api.github.com/users/Christinayar/received_events',
#             'repos_url': 'https://api.github.com/users/Christinayar/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Christinayar/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Christinayar/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Christinayar'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/pulls{/number}',
#   'pushed_at': '2020-06-10T19:45:18Z',
#   'releases_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/releases{/id}',
#   'size': 3713,
#   'ssh_url': 'git@github.com:Christinayar/Geekbrains-Courseworks.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/subscription',
#   'svn_url': 'https://github.com/Christinayar/Geekbrains-Courseworks',
#   'tags_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/tags',
#   'teams_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/teams',
#   'trees_url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks/git/trees{/sha}',
#   'updated_at': '2020-06-10T19:45:21Z',
#   'url': 'https://api.github.com/repos/Christinayar/Geekbrains-Courseworks',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/branches{/branch}',
#   'clone_url': 'https://github.com/Christinayar/Geekbrains-MySQL.git',
#   'collaborators_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/contributors',
#   'created_at': '2020-03-27T20:22:53Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/deployments',
#   'description': 'Выполненные упражнения SQL',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/downloads',
#   'events_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/forks',
#   'full_name': 'Christinayar/Geekbrains-MySQL',
#   'git_commits_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/git/tags{/sha}',
#   'git_url': 'git://github.com/Christinayar/Geekbrains-MySQL.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/hooks',
#   'html_url': 'https://github.com/Christinayar/Geekbrains-MySQL',
#   'id': 250638718,
#   'issue_comment_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/labels{/name}',
#   'language': 'TSQL',
#   'languages_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/merges',
#   'milestones_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Geekbrains-MySQL',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTA2Mzg3MTg=',
#   'notifications_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/49560511?v=4',
#             'events_url': 'https://api.github.com/users/Christinayar/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Christinayar/followers',
#             'following_url': 'https://api.github.com/users/Christinayar/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Christinayar/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Christinayar',
#             'id': 49560511,
#             'login': 'Christinayar',
#             'node_id': 'MDQ6VXNlcjQ5NTYwNTEx',
#             'organizations_url': 'https://api.github.com/users/Christinayar/orgs',
#             'received_events_url': 'https://api.github.com/users/Christinayar/received_events',
#             'repos_url': 'https://api.github.com/users/Christinayar/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Christinayar/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Christinayar/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Christinayar'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/pulls{/number}',
#   'pushed_at': '2020-05-02T14:52:42Z',
#   'releases_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/releases{/id}',
#   'size': 132,
#   'ssh_url': 'git@github.com:Christinayar/Geekbrains-MySQL.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/subscription',
#   'svn_url': 'https://github.com/Christinayar/Geekbrains-MySQL',
#   'tags_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/tags',
#   'teams_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/teams',
#   'trees_url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL/git/trees{/sha}',
#   'updated_at': '2020-05-02T17:01:37Z',
#   'url': 'https://api.github.com/repos/Christinayar/Geekbrains-MySQL',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/branches{/branch}',
#   'clone_url': 'https://github.com/Christinayar/Jupyter_Notebook-Projects.git',
#   'collaborators_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/contributors',
#   'created_at': '2020-05-11T22:58:35Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/deployments',
#   'description': 'Анализ данных: библиотеки Numpy, Pandas, Matplotlib, '
#                  'Scikit-learn',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/downloads',
#   'events_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/forks',
#   'full_name': 'Christinayar/Jupyter_Notebook-Projects',
#   'git_commits_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/git/tags{/sha}',
#   'git_url': 'git://github.com/Christinayar/Jupyter_Notebook-Projects.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/hooks',
#   'html_url': 'https://github.com/Christinayar/Jupyter_Notebook-Projects',
#   'id': 263177407,
#   'issue_comment_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/merges',
#   'milestones_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Jupyter_Notebook-Projects',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMxNzc0MDc=',
#   'notifications_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/49560511?v=4',
#             'events_url': 'https://api.github.com/users/Christinayar/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Christinayar/followers',
#             'following_url': 'https://api.github.com/users/Christinayar/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Christinayar/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Christinayar',
#             'id': 49560511,
#             'login': 'Christinayar',
#             'node_id': 'MDQ6VXNlcjQ5NTYwNTEx',
#             'organizations_url': 'https://api.github.com/users/Christinayar/orgs',
#             'received_events_url': 'https://api.github.com/users/Christinayar/received_events',
#             'repos_url': 'https://api.github.com/users/Christinayar/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Christinayar/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Christinayar/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Christinayar'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/pulls{/number}',
#   'pushed_at': '2020-06-30T13:43:16Z',
#   'releases_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/releases{/id}',
#   'size': 84,
#   'ssh_url': 'git@github.com:Christinayar/Jupyter_Notebook-Projects.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/subscription',
#   'svn_url': 'https://github.com/Christinayar/Jupyter_Notebook-Projects',
#   'tags_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/tags',
#   'teams_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/teams',
#   'trees_url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects/git/trees{/sha}',
#   'updated_at': '2020-06-30T13:43:19Z',
#   'url': 'https://api.github.com/repos/Christinayar/Jupyter_Notebook-Projects',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/Christinayar/LearningSQL/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Christinayar/LearningSQL/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Christinayar/LearningSQL/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Christinayar/LearningSQL/branches{/branch}',
#   'clone_url': 'https://github.com/Christinayar/LearningSQL.git',
#   'collaborators_url': 'https://api.github.com/repos/Christinayar/LearningSQL/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Christinayar/LearningSQL/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Christinayar/LearningSQL/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Christinayar/LearningSQL/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Christinayar/LearningSQL/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Christinayar/LearningSQL/contributors',
#   'created_at': '2020-05-06T16:11:13Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Christinayar/LearningSQL/deployments',
#   'description': 'Упражнения из книги Learning SQL by Alan Beaulieu ',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Christinayar/LearningSQL/downloads',
#   'events_url': 'https://api.github.com/repos/Christinayar/LearningSQL/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Christinayar/LearningSQL/forks',
#   'full_name': 'Christinayar/LearningSQL',
#   'git_commits_url': 'https://api.github.com/repos/Christinayar/LearningSQL/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Christinayar/LearningSQL/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Christinayar/LearningSQL/git/tags{/sha}',
#   'git_url': 'git://github.com/Christinayar/LearningSQL.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Christinayar/LearningSQL/hooks',
#   'html_url': 'https://github.com/Christinayar/LearningSQL',
#   'id': 261812781,
#   'issue_comment_url': 'https://api.github.com/repos/Christinayar/LearningSQL/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Christinayar/LearningSQL/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Christinayar/LearningSQL/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Christinayar/LearningSQL/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Christinayar/LearningSQL/labels{/name}',
#   'language': 'TSQL',
#   'languages_url': 'https://api.github.com/repos/Christinayar/LearningSQL/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Christinayar/LearningSQL/merges',
#   'milestones_url': 'https://api.github.com/repos/Christinayar/LearningSQL/milestones{/number}',
#   'mirror_url': None,
#   'name': 'LearningSQL',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjE4MTI3ODE=',
#   'notifications_url': 'https://api.github.com/repos/Christinayar/LearningSQL/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/49560511?v=4',
#             'events_url': 'https://api.github.com/users/Christinayar/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Christinayar/followers',
#             'following_url': 'https://api.github.com/users/Christinayar/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Christinayar/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Christinayar',
#             'id': 49560511,
#             'login': 'Christinayar',
#             'node_id': 'MDQ6VXNlcjQ5NTYwNTEx',
#             'organizations_url': 'https://api.github.com/users/Christinayar/orgs',
#             'received_events_url': 'https://api.github.com/users/Christinayar/received_events',
#             'repos_url': 'https://api.github.com/users/Christinayar/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Christinayar/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Christinayar/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Christinayar'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Christinayar/LearningSQL/pulls{/number}',
#   'pushed_at': '2020-05-12T22:25:32Z',
#   'releases_url': 'https://api.github.com/repos/Christinayar/LearningSQL/releases{/id}',
#   'size': 16,
#   'ssh_url': 'git@github.com:Christinayar/LearningSQL.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Christinayar/LearningSQL/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Christinayar/LearningSQL/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Christinayar/LearningSQL/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Christinayar/LearningSQL/subscription',
#   'svn_url': 'https://github.com/Christinayar/LearningSQL',
#   'tags_url': 'https://api.github.com/repos/Christinayar/LearningSQL/tags',
#   'teams_url': 'https://api.github.com/repos/Christinayar/LearningSQL/teams',
#   'trees_url': 'https://api.github.com/repos/Christinayar/LearningSQL/git/trees{/sha}',
#   'updated_at': '2020-05-12T22:25:35Z',
#   'url': 'https://api.github.com/repos/Christinayar/LearningSQL',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/Christinayar/Python-Projects/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Christinayar/Python-Projects/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Christinayar/Python-Projects/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Christinayar/Python-Projects/branches{/branch}',
#   'clone_url': 'https://github.com/Christinayar/Python-Projects.git',
#   'collaborators_url': 'https://api.github.com/repos/Christinayar/Python-Projects/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Christinayar/Python-Projects/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Christinayar/Python-Projects/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Christinayar/Python-Projects/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Christinayar/Python-Projects/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Christinayar/Python-Projects/contributors',
#   'created_at': '2020-01-09T18:56:21Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Christinayar/Python-Projects/deployments',
#   'description': 'Выполненные упражнения Python3',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/Christinayar/Python-Projects/downloads',
#   'events_url': 'https://api.github.com/repos/Christinayar/Python-Projects/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/Christinayar/Python-Projects/forks',
#   'full_name': 'Christinayar/Python-Projects',
#   'git_commits_url': 'https://api.github.com/repos/Christinayar/Python-Projects/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Christinayar/Python-Projects/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Christinayar/Python-Projects/git/tags{/sha}',
#   'git_url': 'git://github.com/Christinayar/Python-Projects.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Christinayar/Python-Projects/hooks',
#   'html_url': 'https://github.com/Christinayar/Python-Projects',
#   'id': 232881928,
#   'issue_comment_url': 'https://api.github.com/repos/Christinayar/Python-Projects/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Christinayar/Python-Projects/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Christinayar/Python-Projects/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Christinayar/Python-Projects/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Christinayar/Python-Projects/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/Christinayar/Python-Projects/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/Christinayar/Python-Projects/merges',
#   'milestones_url': 'https://api.github.com/repos/Christinayar/Python-Projects/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Python-Projects',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzI4ODE5Mjg=',
#   'notifications_url': 'https://api.github.com/repos/Christinayar/Python-Projects/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/49560511?v=4',
#             'events_url': 'https://api.github.com/users/Christinayar/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/Christinayar/followers',
#             'following_url': 'https://api.github.com/users/Christinayar/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/Christinayar/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/Christinayar',
#             'id': 49560511,
#             'login': 'Christinayar',
#             'node_id': 'MDQ6VXNlcjQ5NTYwNTEx',
#             'organizations_url': 'https://api.github.com/users/Christinayar/orgs',
#             'received_events_url': 'https://api.github.com/users/Christinayar/received_events',
#             'repos_url': 'https://api.github.com/users/Christinayar/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/Christinayar/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/Christinayar/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/Christinayar'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Christinayar/Python-Projects/pulls{/number}',
#   'pushed_at': '2020-05-30T20:28:09Z',
#   'releases_url': 'https://api.github.com/repos/Christinayar/Python-Projects/releases{/id}',
#   'size': 98,
#   'ssh_url': 'git@github.com:Christinayar/Python-Projects.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/Christinayar/Python-Projects/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Christinayar/Python-Projects/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Christinayar/Python-Projects/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Christinayar/Python-Projects/subscription',
#   'svn_url': 'https://github.com/Christinayar/Python-Projects',
#   'tags_url': 'https://api.github.com/repos/Christinayar/Python-Projects/tags',
#   'teams_url': 'https://api.github.com/repos/Christinayar/Python-Projects/teams',
#   'trees_url': 'https://api.github.com/repos/Christinayar/Python-Projects/git/trees{/sha}',
#   'updated_at': '2020-05-30T20:28:11Z',
#   'url': 'https://api.github.com/repos/Christinayar/Python-Projects',
#   'watchers': 0,
#   'watchers_count': 0}]

# %%
for i in response.json():
    print(i['html_url'])
# Out:
# https://github.com/Christinayar/Geekbrains-Courseworks
# https://github.com/Christinayar/Geekbrains-MySQL
# https://github.com/Christinayar/Jupyter_Notebook-Projects
# https://github.com/Christinayar/LearningSQL
# https://github.com/Christinayar/Python-Projects

# %%
with open('data.json', 'w') as f:
    json.dump(response.json(), f)
