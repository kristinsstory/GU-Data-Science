# %%
import numpy as np
from math import factorial

# %% [markdown]
# **Задание 1**
#
# Из колоды в 52 карты извлекаются случайным образом 4 карты.
# a) Найти вероятность того, что все карты – крести.

# %%
# Условная вероятность
A = 13/52 * 12/51 * 11/50 * 10/49

# %%
print(round(A, 4))
# Out:
# 0.0026

# %%
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %%
# Сколько способов выбрать все крести
combinations(13, 4)
# Out:
# 715

# %%
# Общее число исходов
combinations(52, 4)
# Out:
# 270725

# %%
# Найдем вероятность - число исходов, благоприятствующих нашему событию / общее число исходов
round((715 / 270725),4)
# Out:
# 0.0026

# %% [markdown]
# б) Найти вероятность, что среди 4-х карт окажется хотя бы один туз.

# %%
# Подмножество без тузов, число возможных сочетаний из 4 карт из подмножества 48 карт
combinations(48, 4)
# Out:
# 194580

# %%
# Общее число возможных сочетаний 4 карт из подмножества 52
combinations(52, 4)
# Out:
# 270725

# %%
# Число возможных сочетаний, где из извлеченных карт, хотя бы 1 туз
print(270725 - 194580)
# Out:
# 76145

# %%
# Вероятность вытащить 4 карты с минимум 1 тузом
round((76145 / 270725), 2)
# Out:
# 0.28

# %%
# Сочетание 4 карт из 52, где 1 туз

# %%
combinations(4, 1)
# Out:
# 4

# %%
combinations(48, 3)
# Out:
# 17296

# %%
C1 = 4 * 17296

# %%
print(C1)
# Out:
# 69184

# %%
# Сочетание 4 карт из 52, где 2 туза

# %%
combinations(4, 2)
# Out:
# 6

# %%
combinations(48, 2)
# Out:
# 1128

# %%
C2 = 6 * 1128

# %%
print(C2)
# Out:
# 6768

# %%
# сочетание 4 карт из 52, где 3 туза

# %%
combinations(4, 3)
# Out:
# 4

# %%
combinations(48, 1)
# Out:
# 48

# %%
C3 = 4 * 48

# %%
print(C3)
# Out:
# 192

# %%
# сочетание 4 карт из 52, где 4 туза

# %%
combinations(4, 4)
# Out:
# 1

# %%
combinations(48, 0)
# Out:
# 1

# %%
C4 = 1 * 1

# %%
C = C1 + C2 + C3 + C4

# %%
print(C)
# Out:
# 76145

# %%
# Найдем вероятность - число исходов, благоприятствующих нашему событию / общее число исходов

# %%
76145 / 270725
# Out:
# 0.2812632745405855

# %% [markdown]
# **Задание 2**
# На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %%
# Условная вероятность
3/10 * 2/9 * 1/8
# Out:
# 0.008333333333333333

# %%
combinations(10, 3)
# Out:
# 120

# %%
# Найдем вероятность того, что человек, не знающий код, откроет дверь с первой попытки

# %%
round((1 / 120), 3)
# Out:
# 0.008

# %% [markdown]
# **Задание 3**
# В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?

# %%
# Условная вероятность
round((9/15 * 8/14 * 7/13), 2)
# Out:
# 0.18

# %%
combinations(9, 3) / combinations(15, 3)
# Out:
# 0.18461538461538463

# %% [markdown]
# **Задание 4**
# В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %%
# Условная вероятность
round((2/100 * 1/99), 4)
# Out:
# 0.0002

# %%
# найдем числуо благоприятствующих нашему событию исходов - это число способов выбрать 2 выигрышных билета из 100 возможных

# %%
combinations(2, 2)
# Out:
# 1

# %%
# найдем общее число исходов - это число способов выбрать любые 2 билета из 100 возможных

# %%
combinations(100, 2)
# Out:
# 4950

# %%
1 / 4950
# Out:
# 0.00020202020202020202
